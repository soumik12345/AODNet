# %%
from aodnet.dataloader import DataLoader

# %%
dataloader = DataLoader(
    dataset_path='/Users/soumikrakshit/Workspace/datasets/Dehazing', image_size=(640, 480))
train_dataset, val_dataset = dataloader.get_datasets(val_split=0.2, buffer_size=1024, batch_size=1)

# %%
dataloader.debug_display()
# Out:
# Number of Image Files: 27256
#
# Original Image Files:
# /Users/soumikrakshit/Workspace/datasets/Dehazing/original_images/NYU2_1000.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/original_images/NYU2_1000.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/original_images/NYU2_1000.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/original_images/NYU2_1000.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/original_images/NYU2_1000.jpg
#
# Hazy Image Files:
# /Users/soumikrakshit/Workspace/datasets/Dehazing/train_images/NYU2_1000_1_1.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/train_images/NYU2_1000_1_2.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/train_images/NYU2_1000_1_3.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/train_images/NYU2_1000_2_1.jpg
# /Users/soumikrakshit/Workspace/datasets/Dehazing/train_images/NYU2_1000_2_2.jpg
#
# ...
